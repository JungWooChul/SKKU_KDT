# %%
import re
import os
import unicodedata
import urllib3
import zipfile
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense
from tensorflow.keras.models import Model

# %% [markdown]
# ## Download the data

# %%
# http = urllib3.PoolManager()
# url ='http://www.manythings.org/anki/fra-eng.zip'
# filename = 'fra-eng.zip'
# path = os.getcwd()
# zipfilename = os.path.join(path, filename)


# with http.request('GET', url, preload_content=False) as r, open(zipfilename, 'wb') as out_file:       
#     shutil.copyfileobj(r, out_file)

# with zipfile.ZipFile(zipfilename, 'r') as zip_ref:
#     zip_ref.extractall(path)

# %% [markdown]
# ## Configuration

# %%
BATCH_SIZE = 64  # Batch size for training.
EPOCHS = 100  # Number of epochs to train for.
HIDDEN_DIM = 256  # Latent dimensionality of the encoding space.
EMBEDDING_DIM = 64
NUM_SAMPLES = 33000  # Number of samples to train on.

# %% [markdown]
# ## Prepare the data

# %% [markdown]
# 데이터셋을 다운로드한 후에 데이터를 준비하고자 다음의 단계를 수행합니다.
#
# 1. 각 문장에 start와 end 토큰을 추가합니다.
# 2. 특정 문자를 제거함으로써 문장을 정리합니다.
# 3. 단어 인덱스와 아이디(ID) 인덱스를 생성합니다. (단어 → 아이디(ID), 아이디(ID) → 단어로 매핑된 딕셔너리).
# 4. 각 문장을 입력층의 최대 길이만큼 패딩(padding)을 수행합니다.

# %%
def unicode_to_ascii(s):
  # 프랑스어 악센트(accent) 삭제
  # 예시 : 'déjà diné' -> deja dine
  return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')

# %%
def preprocess_sentence(sent):
  # 악센트 삭제 함수 호출
  sent = unicode_to_ascii(sent.lower())

  # 단어와 구두점 사이에 공백을 만듭니다.
  # Ex) "he is a boy." => "he is a boy ."
  sent = re.sub(r"([?.!,¿])", r" \1", sent) # '?' --> ' \1' --> ' ?'

  # (a-z, A-Z, ".", "?", "!", ",") 이들을 제외하고는 전부 공백으로 변환합니다.
  sent = re.sub(r"[^a-zA-Z!.?]+", r" ", sent)

  # 다수 개의 공백을 하나의 공백으로 치환
  sent = re.sub(r"\s+", " ", sent)
  return sent

# %% [markdown]
# 훈련 과정에서 교사 강요(Teacher Forcing)을 사용할 예정이므로, 훈련 시 사용할 디코더의 입력 시퀀스와 실제값. 즉, 레이블에 해당되는 출력 시퀀스를 따로 분리하여 저장합니다. 입력 시퀀스에는 시작을 의미하는 토큰인 <sos>를 추가하고, 출력 시퀀스에는 종료를 의미하는 토큰인 <eos>를 추가합니다.

# %% [markdown]
# - 교사 강요란(Teacher Forcing)?
#     - 훈련 과정에서는 이전 시점의 디코더 셀의 출력을 현재 시점의 디코더 셀의 입력으로 넣어주지 않고, 이전 시점의 실제값을 현재 시점의 디코더 셀의 입력값으로 하는 방법을 사용할 겁니다. 그 이유는 이전 시점의 디코더 셀의 예측이 틀렸는데 이를 현재 시점의 디코더 셀의 입력으로 사용하면 현재 시점의 디코더 셀의 예측도 잘못될 가능성이 높고 이는 연쇄 작용으로 디코더 전체의 예측을 어렵게 합니다. 이런 상황이 반복되면 훈련 시간이 느려집니다. 만약 이 상황을 원하지 않는다면 이전 시점의 디코더 셀의 예측값 대신 실제값을 현재 시점의 디코더 셀의 입력으로 사용하는 방법을 사용할 수 있습니다. 이와 같이 RNN의 모든 시점에 대해서 이전 시점의 예측값 대신 실제값을 입력으로 주는 방법을 교사 강요라고 합니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# - 방법 1

# %%
# dataset 
eng_corpus, fra_corpus = [], []
with open("/content/drive/MyDrive/Colab Notebooks/06_딥러닝/06_Seq2Seq/fra-eng/fra.txt", "r") as lines:
    for i, line in enumerate(lines):
        # source 데이터와 target 데이터 분리
        tar_line, src_line, _ = line.strip().split('\t')
        
        eng_corpus.append(tar_line)
        fra_corpus.append(src_line)

print(len(eng_corpus), eng_corpus[:10])
print(len(fra_corpus), fra_corpus[:10])
# Out:
# 217975 ['Go.', 'Go.', 'Go.', 'Go.', 'Hi.', 'Hi.', 'Run!', 'Run!', 'Run!', 'Run!']
# 217975 ['Va !', 'Marche.', 'En route !', 'Bouge !', 'Salut !', 'Salut.', 'Cours\u202f!', 'Courez\u202f!', 'Prenez vos jambes à vos cous !', 'File !']

# %% [markdown]
# - 방법 2

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/06_딥러닝/06_Seq2Seq/fra-eng/fra.txt', sep = '\t', header = None, names = ['eng', 'fra', 'desc'])

eng_corpus = df['eng'].to_list()
fra_corpus = df['fra'].to_list()

print(len(eng_corpus), eng_corpus[:10])
print(len(fra_corpus), fra_corpus[:10])
# Out:
# 217975 ['Go.', 'Go.', 'Go.', 'Go.', 'Hi.', 'Hi.', 'Run!', 'Run!', 'Run!', 'Run!']
# 217975 ['Va !', 'Marche.', 'En route !', 'Bouge !', 'Salut !', 'Salut.', 'Cours\u202f!', 'Courez\u202f!', 'Prenez vos jambes à vos cous !', 'File !']

# %%
df.head(10)
# Out:
#     eng                             fra  \
# 0   Go.                            Va !
# 1   Go.                         Marche.
# 2   Go.                      En route !
# 3   Go.                         Bouge !
# 4   Hi.                         Salut !
# 5   Hi.                          Salut.
# 6  Run!                         Cours !
# 7  Run!                        Courez !
# 8  Run!  Prenez vos jambes à vos cous !
# 9  Run!                          File !
#
#                                                 desc
# 0  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 1  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 2  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 3  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 4  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 5  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 6  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 7  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 8  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 9  CC-BY 2.0 (France) Attribution: tatoeba.org #9...

# %%
s = 'example'
print("<sos> " + s)
print(s + " <eos>")
# Out:
# <sos> example
# example <eos>

# %%
def load_preprocessed_data(eng_corpus, fra_corpus):
    encoder_input, decoder_input, decoder_target = [], [], []

    for i, (src_line, tar_line) in enumerate(zip(fra_corpus, eng_corpus)):
        # source 데이터 전처리
        src_line = [w for w in preprocess_sentence(src_line).split()]

        # target 데이터 전처리
        tar_line = preprocess_sentence(tar_line)
        tar_line_in = [w for w in ("<sos> " + tar_line).split()]  # teacher forcing을 위한 정답셋 
        tar_line_out = [w for w in (tar_line + " <eos>").split()]

        encoder_input.append(src_line) # 클리닝 
        decoder_input.append(tar_line_in) # 클리닝 + sos 
        decoder_target.append(tar_line_out) # 클리닝 + eos 

        if i == NUM_SAMPLES - 1:
            break
                    
    return encoder_input, decoder_input, decoder_target

# %%
# # 코드 재구성
# def load_preprocessed_data(eng_corpus, fra_corpus):
#     encoder_input, decoder_input, decoder_target = [], [], []

#     for i, (src_line, tar_line) in enumerate(zip(fra_corpus, eng_corpus)):
#         # source 데이터 전처리
#         src_line = preprocess_sentence(src_line).split()

#         # target 데이터 전처리
#         tar_line = preprocess_sentence(tar_line).split
#         tar_line_in = ['<sos> '] + tar_line # teacher forcing을 위한 정답셋 
#         tar_line_out = tar_line + ['<eos> ']

#         encoder_input.append(src_line) # 클리닝 
#         decoder_input.append(tar_line_in) # 클리닝 + sos 
#         decoder_target.append(tar_line_out) # 클리닝 + eos 

#         # 내가 학습하기로 했던 샘플 수가 되면 break
#         if i == NUM_SAMPLES - 1:
#             break
                    
#     return encoder_input, decoder_input, decoder_target

# %%
# 전처리 테스트
en_sent = u"Have you had dinner?"
fr_sent = u"Avez-vous déjà diné?"

print('전처리 전 영어 문장 :', en_sent)
print('전처리 후 영어 문장 :',preprocess_sentence(en_sent))
print('전처리 전 프랑스어 문장 :', fr_sent)
print('전처리 후 프랑스어 문장 :', preprocess_sentence(fr_sent))
# Out:
# 전처리 전 영어 문장 : Have you had dinner?
# 전처리 후 영어 문장 : have you had dinner ?
# 전처리 전 프랑스어 문장 : Avez-vous déjà diné?
# 전처리 후 프랑스어 문장 : avez vous deja dine ?

# %%
sents_fra_in, sents_en_in, sents_en_out  = load_preprocessed_data(eng_corpus, fra_corpus)

# %%
print('인코더의 입력 :',sents_fra_in[-5:]) # encoder input o, target x
print('디코더의 입력 :',sents_en_in[-5:])
print('디코더의 레이블 :',sents_en_out[-5:])
# Out:
# 인코더의 입력 : [['je', 'veux', 'voir', 'tom', '.'], ['je', 'veux', 'en', 'voir', 'davantage', '.'], ['je', 'veux', 'voir', 'ca', '.'], ['je', 'veux', 'les', 'voir', '.'], ['je', 'veux', 'voir', 'ceci', '.']]
# 디코더의 입력 : [['<sos>', 'i', 'want', 'to', 'meet', 'tom', '.'], ['<sos>', 'i', 'want', 'to', 'see', 'more', '.'], ['<sos>', 'i', 'want', 'to', 'see', 'that', '.'], ['<sos>', 'i', 'want', 'to', 'see', 'them', '.'], ['<sos>', 'i', 'want', 'to', 'see', 'this', '.']]
# 디코더의 레이블 : [['i', 'want', 'to', 'meet', 'tom', '.', '<eos>'], ['i', 'want', 'to', 'see', 'more', '.', '<eos>'], ['i', 'want', 'to', 'see', 'that', '.', '<eos>'], ['i', 'want', 'to', 'see', 'them', '.', '<eos>'], ['i', 'want', 'to', 'see', 'this', '.', '<eos>']]

# %% [markdown]
# 단어집합을 생성하겠습니다.

# %%
# 프랑스어 (encoder)
tokenizer_enc = Tokenizer(filters="", lower=False)
tokenizer_enc.fit_on_texts(sents_fra_in) # vocab dictionary 생성

# 인코더 데이터
encoder_input = tokenizer_enc.texts_to_sequences(sents_fra_in) # encoder 입력

# %%
# 영어 (decoder)
tokenizer_dec = Tokenizer(filters="", lower=False)
tokenizer_dec.fit_on_texts(sents_en_in) # vocab dictionary 생성
tokenizer_dec.fit_on_texts(sents_en_out) # vocab dictionary 생성

# 디코더 데이터
decoder_input = tokenizer_dec.texts_to_sequences(sents_en_in) # decoder의 입력
decoder_target = tokenizer_dec.texts_to_sequences(sents_en_out) # decoder의 출력

# %%
print(sents_fra_in[-5:])
print(sents_en_in[-5:])
print(sents_en_out[-5:])
print('-'*200)
print(encoder_input[-5:])
print(decoder_input[-5:])
print(decoder_target[-5:])
# Out:
# [['je', 'veux', 'voir', 'tom', '.'], ['je', 'veux', 'en', 'voir', 'davantage', '.'], ['je', 'veux', 'voir', 'ca', '.'], ['je', 'veux', 'les', 'voir', '.'], ['je', 'veux', 'voir', 'ceci', '.']]
# [['<sos>', 'i', 'want', 'to', 'meet', 'tom', '.'], ['<sos>', 'i', 'want', 'to', 'see', 'more', '.'], ['<sos>', 'i', 'want', 'to', 'see', 'that', '.'], ['<sos>', 'i', 'want', 'to', 'see', 'them', '.'], ['<sos>', 'i', 'want', 'to', 'see', 'this', '.']]
# [['i', 'want', 'to', 'meet', 'tom', '.', '<eos>'], ['i', 'want', 'to', 'see', 'more', '.', '<eos>'], ['i', 'want', 'to', 'see', 'that', '.', '<eos>'], ['i', 'want', 'to', 'see', 'them', '.', '<eos>'], ['i', 'want', 'to', 'see', 'this', '.', '<eos>']]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [[2, 68, 124, 5, 1], [2, 68, 23, 124, 391, 1], [2, 68, 124, 27, 1], [2, 68, 31, 124, 1], [2, 68, 124, 98, 1]]
# [[2, 4, 51, 21, 631, 7, 1], [2, 4, 51, 21, 72, 181, 1], [2, 4, 51, 21, 72, 16, 1], [2, 4, 51, 21, 72, 104, 1], [2, 4, 51, 21, 72, 20, 1]]
# [[4, 51, 21, 631, 7, 1, 3], [4, 51, 21, 72, 181, 1, 3], [4, 51, 21, 72, 16, 1, 3], [4, 51, 21, 72, 104, 1, 3], [4, 51, 21, 72, 20, 1, 3]]

# %% [markdown]
# 샘플은 총 33,000개 존재하며 영어 문장의 길이는 8, 프랑스어 문장의 길이는 16입니다. 단어 집합의 크기를 정의합니다.

# %%
print(tokenizer_enc.word_index)
print(tokenizer_dec.word_index)
# Out:
# {'.': 1, 'je': 2, 'est': 3, '?': 4, 'tom': 5, 'a': 6, 'vous': 7, '!': 8, 'j': 9, 'pas': 10, 'il': 11, 'ai': 12, 'nous': 13, 'le': 14, 'de': 15, 'tu': 16, 'ne': 17, 'c': 18, 'suis': 19, 'la': 20, 'l': 21, 'un': 22, 'en': 23, 'ce': 24, 'n': 25, 'me': 26, 'ca': 27, 'etes': 28, 'que': 29, 'une': 30, 'les': 31, 'moi': 32, 'es': 33, 'd': 34, 's': 35, 'sommes': 36, 't': 37, 'y': 38, 'sont': 39, 'm': 40, 'elle': 41, 'fait': 42, 'etait': 43, 'ils': 44, 'qui': 45, 'aime': 46,
looks': 134, 'tell': 135, 'think': 136, 'say': 137, 'drink': 138, 'late': 139, 'make': 140, 'fun': 141, 'could': 142, 'mine': 143, 'hurt': 144, 'about': 145, 'over': 146, 'tired': 147, 'ok': 148, 'off': 149, 'money': 150, 'left': 151, 'call': 152, 'should': 153, 'book': 154, 'some': 155, 'talk': 156, 'safe': 157, 'read': 158, 'kept': 159, 'careful': 160, 'came': 161, 'lot': 162, 'wrong': 163, 'likes': 164, 'french': 165, 'trust': 166, 'old': 167, 'open': 168, 'wasn': 169, 'really': 170, 'new': 171, 'live': 172, 'funny': 173, 'our': 174, 'sit': 175, 'enough': 176, 'hurry': 177, 'run': 178, 'cold': 179, 'died': 180, 'more': 181, 'sure': 182, 'bed': 183, 'day': 184, 'room': 185, 'said': 186, 'easy': 187, 'much': 188, 'way': 189, 'ask': 190, 'hope': 191, 'broke': 192, 'idea': 193, 'find': 194, 'd': 195, 'loves': 196, 'hard': 197, 'hear': 198, 'nobody': 199, 'miss': 200, 'today': 201, 'gave': 202, 'everybody': 203, 'crazy': 204, 'upset': 205, 'watch': 206, 'both': 207, 'everything': 208, 'sad': 209, 'man': 210, 'found': 211, 'cat': 212, 'seems': 213, 'win': 214, 'aren': 215, 'lucky': 216, 'water': 217, 'sleep': 218, 'sick': 219, 'die': 220, 'yours': 221, 'life': 222, 'by': 223, 'door': 224, 'knew': 225, 'forget': 226, 'mad': 227, 'anyone': 228, 'better': 229, 'pay': 230, 'bit': 231, 'nothing': 232, 'play': 233, 'quit': 234, 'free': 235, 'early': 236, 'called': 237, 'buy': 238, 'care': 239, 'angry': 240, 'turn': 241, 'bring': 242, 'fine': 243, 'swim': 244, 'walk': 245, 'dead': 246, 'true': 247, 'these': 248, 'gone': 249, 'stupid': 250, 'friends': 251, 'house': 252, 'sing': 253, 'put': 254, 'and': 255, 'name': 256, 'heard': 257, 'great': 258, 'school': 259, 'check': 260, 'eyes': 261, 'hand': 262, 'cool': 263, 'fast': 264, 'mean': 265, 'close': 266, 'kidding': 267, 'took': 268, 'looked': 269, 'tall': 270, 'shot': 271, 'sat': 272, 'hungry': 273, 'beer': 274, 'working': 275, 'fat': 276, 'move': 277, 'perfect': 278, 'stand': 279, 'drunk': 280, 'first': 281, 'knows': 282, 'wine': 283, 'needed': 284, 'speak': 285, 'quiet': 286, 'serious': 287, 'enjoy': 288, 'best': 289, 'doing': 290, 'calm': 291, 'show': 292, 'answer': 293, 'coming': 294, 'yourself': 295, 'ate': 296, 'hold': 297, 'cry': 298, 'liked': 299, 'remember': 300, 'anybody': 301, 'only': 302, 'scared': 303, 'yet': 304, 'sorry': 305, 'outside': 306, 'loved': 307, 'boy': 308, 'hat': 309, 'key': 310, 'running': 311, 'been': 312, 'from': 313, 'fix': 314, 'ahead': 315, 'start': 316,  ...

# %%
SRC_VOCAB_SIZE = len(tokenizer_enc.word_index) + 1
TAR_VOCAB_SIZE = len(tokenizer_dec.word_index) + 1

print(f"프랑스 단어 집합의 크기 : {SRC_VOCAB_SIZE}, 영어 단어 집합의 크기 : {TAR_VOCAB_SIZE}")
# Out:
# 영어 단어 집합의 크기 : 7905, 프랑스어 단어 집합의 크기 : 4518

# %% [markdown]
# 각 문장을 입력층의 최대 길이만큼 패딩(padding)을 수행합니다.

# %%
encoder_input = pad_sequences(encoder_input, padding='post')
decoder_input = pad_sequences(decoder_input, padding='post')
decoder_target = pad_sequences(decoder_target, padding='post')

# %%
print('인코더의 입력의 크기(shape) :',encoder_input.shape)
print('디코더의 입력의 크기(shape) :',decoder_input.shape)
print('디코더의 레이블의 크기(shape) :',decoder_target.shape)

# 변수 저장
MAX_ENC_LEN, MAX_DEC_LEN = encoder_input.shape[1], decoder_input.shape[1]
MAX_ENC_LEN, MAX_DEC_LEN
# Out:
# 인코더의 입력의 크기(shape) : (33000, 15)
# 디코더의 입력의 크기(shape) : (33000, 8)
# 디코더의 레이블의 크기(shape) : (33000, 8)
# (15, 8)

# %% [markdown]
# 단어로부터 정수를 얻는 딕셔너리와 정수로부터 단어를 얻는 딕셔너리를 각각 만들어줍니다. 이들은 훈련을 마치고 예측값과 실제값을 비교하는 단계에서 사용합니다.

# %%
# 글자를 숫자로,      숫자를 글자로 mapping_table
# -> 새로운 번역 입력  -> model에서 출력된 결과를 읽을 수 있는 형태로 변경
src2idx = tokenizer_enc.word_index  # word : idx
idx2src = tokenizer_enc.index_word  # idx : word
tar2idx = tokenizer_dec.word_index # word : idx
idx2tar = tokenizer_dec.index_word # idx : word

# %%
print(src2idx)
print(idx2src)
print(tar2idx)
print(idx2tar)
# Out:
# {'.': 1, 'je': 2, 'est': 3, '?': 4, 'tom': 5, 'a': 6, 'vous': 7, '!': 8, 'j': 9, 'pas': 10, 'il': 11, 'ai': 12, 'nous': 13, 'le': 14, 'de': 15, 'tu': 16, 'ne': 17, 'c': 18, 'suis': 19, 'la': 20, 'l': 21, 'un': 22, 'en': 23, 'ce': 24, 'n': 25, 'me': 26, 'ca': 27, 'etes': 28, 'que': 29, 'une': 30, 'les': 31, 'moi': 32, 'es': 33, 'd': 34, 's': 35, 'sommes': 36, 't': 37, 'y': 38, 'sont': 39, 'm': 40, 'elle': 41, 'fait': 42, 'etait': 43, 'ils': 44, 'qui': 45, 'aime': 46, 'tout': 47, 'as': 48, 'mon': 49, 'des': 50, 'elles': 51, 'te': 52, 'bien': 53, 'toi': 54, 'ici': 55, 'peux': 56, 'besoin': 57, 'avez': 58, 'du': 59, 'ete': 60, 'tres': 61, 'qu': 62, 'se': 63, 'faire': 64, 'avons': 65, 'va': 66, 'cela': 67, 'veux': 68, 'on': 69, 'air': 70, 'votre': 71, 'faut': 72, 'fais': 73, 'personne': 74, 'comment': 75, 'ont': 76, 'etais': 77, 'ton': 78, 'aller': 79, 'tous': 80, 'adore': 81, 'monde': 82, 'trop': 83, 'ma': 84, 'ou': 85, 'au': 86, 'maintenant': 87, 'pour': 88, 'soyez': 89, 'mal': 90, 'train': 91, 'plait': 92, 'bon': 93, 'dois': 94, 'etre': 95, 'sois': 96, 'lui': 97, 'ceci': 98, 'peut': 99, 'sens': 100
# {1: '.', 2: 'je', 3: 'est', 4: '?', 5: 'tom', 6: 'a', 7: 'vous', 8: '!', 9: 'j', 10: 'pas', 11: 'il', 12: 'ai', 13: 'nous', 14: 'le', 15: 'de', 16: 'tu', 17: 'ne', 18: 'c', 19: 'suis', 20: 'la', 21: 'l', 22: 'un', 23: 'en', 24: 'ce', 25: 'n', 26: 'me', 27: 'ca', 28: 'etes', 29: 'que', 30: 'une', 31: 'les', 32: 'moi', 33: 'es', 34: 'd', 35: 's', 36: 'sommes', 37: 't', 38: 'y', 39: 'sont', 40: 'm', 41: 'elle', 42: 'fait', 43: 'etait', 44: 'ils', 45: 'qui', 46: 'aime', 47: 'tout', 48: 'as', 49: 'mon', 50: 'des', 51: 'elles', 52: 'te', 53: 'bien', 54: 'toi', 55: 'ici', 56: 'peux', 57: 'besoin', 58: 'avez', 59: 'du', 60: 'ete', 61: 'tres', 62: 'qu', 63: 'se', 64: 'faire', 65: 'avons', 66: 'va', 67: 'cela', 68: 'veux', 69: 'on', 70: 'air', 71: 'votre', 72: 'faut', 73: 'fais', 74: 'personne', 75: 'comment', 76: 'ont', 77: 'etais', 78: 'ton', 79: 'aller', 80: 'tous', 81: 'adore', 82: 'monde', 83: 'trop', 84: 'ma', 85: 'ou', 86: 'au', 87: 'maintenant', 88: 'pour', 89: 'soyez', 90: 'mal', 91: 'train', 92: 'plait', 93: 'bon', 94: 'dois', 95: 'etre', 96: 'sois', 97: 'lui', 98: 'ceci', 99: 'peut', 100: 'sens', 101: 'laisse', 102: 'deteste', 103: 'sur', 104: 'cette', 105: 'dans', 106: 'partir', 107: 'puis', 108: 'pourquoi', 109: 'comme', 110: 'arrete', 111: 'si', 112: 'vu', 113: 'toutes', 114: 'plus', 115: 'faites', 116: 'avec', 117: 'maison', 118: 'voiture', 119: 'sais', 120: 'vais', 121: 'dit', 122: 'jamais', 123: 'ta', 124: 'voir', 125: 'reste', 126: 'donne', 127: 'chien', 128: 'quel', 129: 'quelle', 130: 'aide', 131: 'temps', 132: 'aider', 133: 'laissez', 134: 'viens', 135: 'encore', 136: 'beaucoup', 137: 'vraiment', 138: 'fort', 139: 'deux', 140: 'prends', 141: 'rien', 142: 'seul', 143: 'nouveau', 144: 'travail', 145: 'confiance', 146: 'pouvez', 147: 'perdu', 148: 'passe', 149: 'allez', 150: 'porte', 151: 'bonne', 152: 'juste', 153: 'regarde', 154: 'mange', 155: 'parle', 156: 'argent', 157: 'trouve', 158: 'prie', 159: 'mes', 160: 'tellement', 161: 'arrive', 162: 'prenez', 163: 'chez', 164: 'restez', 165: 'quelqu', 166: 'livre', 167: 'eu', 168: 'son', 169: 'avait', 170: 'marie', 171: 'peu', 172: 'heureux', 173: 'quoi', 174: 'pouvons', 175: 'dis', 176: 'accord', 177: 'connais', 178: 'francais', 179: 'arretez', 180: 'notre', 181: 'coup', 182: 'allons', 183: 'parler', 184: 'idee', 185: 'pris', 186: 'voici', 187: 'vie', 188: 'agit', 189: 'non', 190: 'assez', 191: 'grand', 192: 'semble', 193: 'occupe', 194: 'pense', 195: 'marche', 196: 'calme', 197: 'tard', 198: 'continue', 199: 'manger', 200: 'apprecie', 201: 'termine', 202: 'fini', 203: 'chose', 204: 'heure', 205: 'aujourd', 206: 'hui', 207: 'vrai', 208: 'demande', 209: 'meme', 210: 'malade', 211: 'sait', 212: 'mort', 213: 'avais', 214: 'veuillez', 215: 'gagne', 216: 'vite', 217: 'pret', 218: 'mieux', 219: 'peur', 220: 'toujours', 221: 'securite', 222: 'lit', 223: 'fatigue', 224: 'entendu', 225: 'chercher', 226: 'homme', 227: 'ci', 228: 'essaie', 229: 'yeux', 230: 'simplement', 231: 'triste', 232: 'attention', 233: 'dire', 234: 'sans', 235: 'travaille', 236: 'vas', 237: 'avoir', 238: 'senti', 239: 'eau', 240: 'par', 241: 'bizarre', 242: 'mauvais', 243: 'chanter', 244: 'faim', 245: 'devrais', 246: 'manque', 247: 'fut', 248: 'quelque', 249: 'essaye', 250: 'boulot', 251: 'tete', 252: 'colere', 253: 'tranquille', 254: 'gros', 255: 'froid', 256: 'vue', 257: 'fou', 258: 'raison', 259: 'donnez', 260: 'main', 261: 'regardez', 262: 'chance', 263: 'venir', 264: 'deja', 265: 'tes', 266: 'tomber', 267: 'essayer', 268: 'mourir', 269: 'etions', 270: 'parti', 271: 'oublie', 272: 'retard', 273: 'chat', 274: 'vois', 275: 'travailler', 276: 'et', 277: 'ecole', 278: 'vos', 279: 'dites', 280: 'seule', 281: 'arme', 282: 'blesse', 283: 'alle', 284: 'veut', 285: 'sa', 286: 'aimes', 287: 'aussi', 288: 'joue', 289: 'attendre', 290: 'biere', 291: 'pourrait', 292: 'venez', 293: 'courir', 294: 'espere', 295: 'vin', 296: 'nager', 297: 'fils', 298: 'dessus', 299: 'idiot', 300: 'lire', 301: 'aux', 302: 'dispose', 303: ' ...
# {'.': 1, '<sos>': 2, '<eos>': 3, 'i': 4, 'you': 5, '?': 6, 'tom': 7, 'it': 8, 's': 9, 'is': 10, 'a': 11, 're': 12, 'we': 13, 't': 14, 'm': 15, 'that': 16, 'he': 17, 'the': 18, 'me': 19, 'this': 20, 'to': 21, 'was': 22, 'are': 23, 'do': 24, '!': 25, 'can': 26, 'they': 27, 'have': 28, 'go': 29, 'don': 30, 'my': 31, 'your': 32, 'be': 33, 'll': 34, 'not': 35, 'what': 36, 'did': 37, 'here': 38, 'no': 39, 'like': 40, 'all': 41, 'let': 42, 'she': 43, 'how': 44, 'in': 45, 'get': 46, 'up': 47, 'need': 48, 'on': 49, 'very': 50, 'want': 51, 'love': 52, 'one': 53, 'who': 54, 'know': 55, 'him': 56, 'come': 57, 'out': 58, 'got': 59, 'please': 60, 'just': 61, 'look': 62, 'now': 63, 'so': 64, 'help': 65, 
all': 270, 'shot': 271, 'sat': 272, 'hungry': 273, 'beer': 274, 'working': 275, 'fat': 276, 'move': 277, 'perfect': 278, 'stand': 279, 'drunk': 280, 'first': 281, 'knows': 282, 'wine': 283, 'needed': 284, 'speak': 285, 'quiet': 286, 'serious': 287, 'enjoy': 288, 'best': 289, 'doing': 290, 'calm': 291, 'show': 292, 'answer': 293, 'coming': 294, 'yourself': 295, 'ate': 296, 'hold': 297, 'cry': 298, 'liked': 299, 'remember': 300, 'anybody': 301, 'only': 302, 'scared': 303, 'yet': 304, 'sorry': 305, 'outside': 306, 'loved': 307, 'boy': 308, 'hat': 309, 'key': 310, 'running': 311, 'been': 312, 'from': 313, 'fix': 314, 'ahead': 315, 'start': 316,  ...
# {1: '.', 2: '<sos>', 3: '<eos>', 4: 'i', 5: 'you', 6: '?', 7: 'tom', 8: 'it', 9: 's', 10: 'is', 11: 'a', 12: 're', 13: 'we', 14: 't', 15: 'm', 16: 'that', 17: 'he', 18: 'the', 19: 'me', 20: 'this', 21: 'to', 22: 'was', 23: 'are', 24: 'do', 25: '!', 26: 'can', 27: 'they', 28: 'have', 29: 'go', 30: 'don', 31: 'my', 32: 'your', 33: 'be', 34: 'll', 35: 'not', 36: 'what', 37: 'did', 38: 'here', 39: 'no', 40: 'like', 41: 'all', 42: 'let', 43: 'she', 44: 'how', 45: 'in', 46: 'get', 47: 'up', 48: 'need', 49: 'on', 50: 'very', 51: 'want', 52: 'love', 53: 'one', 54: 'who', 55: 'know', 56: 'him', 57: 'come', 58: 'out', 59: 'got', 60: 'please', 61: 'just', 62: 'look', 63: 'now', 64: 'so', 65: 'help', 66: 'there', 67: 'us', 68: 'too', 69: 'stop', 70: 'take', 71: 'of', 72: 'see', 73: 'good', 74: 'will', 75: 'were', 76: 'for', 77: 've', 78: 'am', 79: 'has', 80: 'had', 81: 'at', 82: 'give', 83: 'must', 84: 'where', 85: 'saw', 86: 'keep', 87: 'feel', 88: 'back', 89: 'try', 90: 'home', 91: 'work', 92: 'alone', 93: 'stay', 94: 'didn', 95: 'leave', 96: 'happy', 97: 'why', 98: 'isn', 99: 'hate', 100: 'everyone', 101: 'again', 102: 'lost', 103: 'her', 104: 'them', 105: 'car', 106: 'won', 107: 'busy', 108: 'eat', 109: 'an', 110: 'made', 111: 'his', 112: 'time', 113: 'felt', 114: 'may', 115: 'right', 116: 'went', 117: 'never', 118: 'dog', 119: 'well', 120: 'down', 121: 'wait', 122: 'job', 123: 'with', 124: 'does', 125: 'away', 126: 'ready', 127: 'going', 128: 'mary', 129: 'still', 130: 'nice', 131: 'done', 132: 'bad', 133: 'big', 134: 'looks', 135: 'tell', 136: 'think', 137: 'say', 138: 'drink', 139: 'late', 140: 'make', 141: 'fun', 142: 'could', 143: 'mine', 144: 'hurt', 145: 'about', 146: 'over', 147: 'tired', 148: 'ok', 149: 'off', 150: 'money', 151: 'left', 152: 'call', 153: 'should', 154: 'book', 155: 'some', 156: 'talk', 157: 'safe', 158: 'read', 159: 'kept', 160: 'careful', 161: 'came', 162: 'lot', 163: 'wrong', 164: 'likes', 165: 'french', 166: 'trust', 167: 'old', 168: 'open', 169: 'wasn', 170: 'really', 171: 'new', 172: 'live', 173: 'funny', 174: 'our', 175: 'sit', 176: 'enough', 177: 'hurry', 178: 'run', 179: 'cold', 180: 'died', 181: 'more', 182: 'sure', 183: 'bed', 184: 'day', 185: 'room', 186: 'said', 187: 'easy', 188: 'much', 189: 'way', 190: 'ask', 191: 'hope', 192: 'broke', 193: 'idea', 194: 'find', 195: 'd', 196: 'loves', 197: 'hard', 198: 'hear', 199: 'nobody', 200: 'miss', 201: 'today', 202: 'gave', 203: 'everybody', 204: 'crazy', 205: 'upset', 206: 'watch', 207: 'both', 208: 'everything', 209: 'sad', 210: 'man', 211: 'found', 212: 'cat', 213: 'seems', 214: 'win', 215: 'aren', 216: 'lucky', 217: 'water', 218: 'sleep', 219: 'sick', 220: 'die', 221: 'yours', 222: 'life', 223: 'by', 224: 'door', 225: 'knew', 226: 'forget', 227: 'mad', 228: 'anyone', 229: 'better', 230: 'pay', 231: 'bit', 232: 'nothing', 233: 'play', 234: 'quit', 235: 'free', 236: 'early', 237: 'called', 238: 'buy', 239: 'care', 240: 'angry', 241: 'turn', 242: 'bring', 243: 'fine', 244: 'swim', 245: 'walk', 246: 'dead', 247: 'true', 248: 'these', 249: 'gone', 250: 'stupid', 251: 'friends', 252: 'house', 253: 'sing', 254: 'put', 255: 'and', 256: 'name', 257: 'heard', 258: 'great', 259: 'school', 260: 'check', 261: 'eyes', 262: 'hand', 263: 'cool', 264: 'fast', 265: 'mean', 266: 'close', 267: 'kidding', 268: 'took', 269: 'looked', 270: 'tall', 271: 'shot', 272: 'sat', 273: 'hungry', 274: 'beer', 275: 'working', 276: 'fat', 277: 'move', 278: 'perfect', 279: 'stand', 280: 'drunk', 281: 'first', 282: 'knows', 283: 'wine', 284: 'needed', 285: 'speak', 286: 'quiet', 287: 'serious', 288: 'enjoy', 289: 'best', 290: 'doing', 291: 'calm', 292: 'show', 293: 'answer', 294: 'coming', 295: 'yourself', 296: 'ate', 297: 'hold', 298: 'cry', 299: 'liked', 300: 'remember', 301: 'anybody', 302: 'only', 303: 'scared', 304: 'yet', 305: 'sorry', 306: 'outside', 307: 'loved', 308: 'boy', 309: 'hat', 310: 'key', 311: 'running', 312: 'been', 313: 'from', 314: 'fix', 315: 'ahead', 316: 'start',  ...

# %% [markdown]
# 테스트 데이터를 분리하겠습니다. 인코더 input, 디코더 input, 디코더 output이 동일하게 분리되어야 하기 때문에 랜덤한 정수배열을 만들어 직접 나누겠습니다.

# %% [markdown]
# 우선 랜덤하게 시퀀스를 섞습니다.

# %%
# 랜덤 인덱스 생성 
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print('랜덤 시퀀스 :',indices)

# 랜덤하게 섞기 - 랜덤하게 섞이지만 3개의 dataset이 동일하게 섞임
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

print()
print(decoder_input[indices[0]])
print(decoder_target[indices[0]])
# Out:
# 랜덤 시퀀스 : [19556 28702  9574 ...  3389  7480 14535]
#
# [ 2  4 48 21 29 90  1  0]
# [ 4 48 21 29 90  1  3  0]

# %% [markdown]
# `<sos>` `<eos>` 토큰을 제외한 다른 단어들은 동일한 인덱스를 갖고 있어야 합니다.

# %% [markdown]
# 10%의 데이터를 test데이터로 분리하겠습니다.

# %%
n_of_train = int(NUM_SAMPLES*0.9) # 900

# train data
encoder_input_train = encoder_input[:n_of_train] 
decoder_input_train = decoder_input[:n_of_train]
decoder_target_train = decoder_target[:n_of_train]

# test data
encoder_input_test = encoder_input[n_of_train:]
decoder_input_test = decoder_input[n_of_train:]
decoder_target_test = decoder_target[n_of_train:]

# %%
print('훈련 source 데이터의 크기 :',encoder_input_train.shape)
print('훈련 target 데이터의 크기 :',decoder_input_train.shape)
print('훈련 target 레이블의 크기 :',decoder_target_train.shape)
print('테스트 source 데이터의 크기 :',encoder_input_test.shape)
print('테스트 target 데이터의 크기 :',decoder_input_test.shape)
print('테스트 target 레이블의 크기 :',decoder_target_test.shape)
# Out:
# 훈련 source 데이터의 크기 : (29700, 15)
# 훈련 target 데이터의 크기 : (29700, 8)
# 훈련 target 레이블의 크기 : (29700, 8)
# 테스트 source 데이터의 크기 : (3300, 15)
# 테스트 target 데이터의 크기 : (3300, 8)
# 테스트 target 레이블의 크기 : (3300, 8)

# %% [markdown]
# ## 모델링 (학습)

# %% [markdown]
# #### 1. 인코더

# %% [markdown]
# 인코더를 설계합니다.
#
# LSTM 레이어를 사용하므로 context vector는 `hidden state`와 `cell state` 총 2가지 모두를 사용합니다.
# - 이 두 가지 상태를 encoder_states로 묶어서 저장하겠습니다.

# %% [markdown]
# #### 2. 디코더

# %% [markdown]
# 1. 디코더는 인코더의 마지막 은닉 상태로부터 초기 은닉 상태를 얻습니다.
#     - initial_state의 인자값으로 encoder_states를 주는 코드가 이에 해당됩니다.
#
# 2. 디코더도 은닉 상태, 셀 상태를 리턴하기는 하지만 훈련 과정에서는 사용하지 않습니다. (Teacher Forcing을 위해)
#
# 3. seq2seq의 디코더는 기본적으로 각 시점마다 다중 클래스 분류 문제를 풀고있습니다.
#     - 매 시점마다 프랑스어 단어 집합의 크기(tar_vocab_size)의 선택지에서 단어를 1개 선택하여 이를 이번 시점에서 예측한 단어로 택합니다.
#     - 다중 클래스 분류 문제이므로 출력층으로 소프트맥스 함수와 손실 함수를 크로스 엔트로피 함수를 사용합니다.
#         - categorical_crossentropy를 사용하려면 레이블은 원-핫 인코딩이 된 상태여야 합니다
#         - 그런데 현재 decoder_outputs의 경우에는 원-핫 인코딩을 하지 않은 상태입니다.
#         - 원-핫 인코딩을 하지 않은 상태로 정수 레이블에 대해서 다중 클래스 분류 문제를 풀고자 하는 경우에는 `categorical_crossentropy`가 아니라 `sparse_categorical_crossentropy`를 사용하면 됩니다.

# %%
# 인코더 (Train)

## 층 
enc_emb_layer = Embedding(SRC_VOCAB_SIZE, EMBEDDING_DIM)
encoder_lstm = LSTM(HIDDEN_DIM, return_state = True) # 상태값 리턴을 위해 return_state는 True


## input -> output 
encoder_inputs = Input(shape=(None, )) # 입력
enc_emb = enc_emb_layer(encoder_inputs) # 단어 임베딩
encoder_outputs, state_h, state_c =  encoder_lstm(enc_emb) # LSTM

encoder_states = [state_h, state_c] # 인코더의 은닉 상태와 셀 상태를 리스트로 저장 (encoder의 output --> context vector)

# %%
# 디코더 (Train)
decoder_inputs = Input(shape=(None, ))

## 층
#상태값 리턴을 위해 lstm layer return_state는 True, 모든 시점에 대해서 단어를 예측하기 위해 return_sequences는 True
dec_emb_layer = Embedding(TAR_VOCAB_SIZE, HIDDEN_DIM)
decoder_lstm = LSTM(HIDDEN_DIM, return_sequences=True, return_state = True) 
decoder_dense = Dense(TAR_VOCAB_SIZE, activation = 'softmax')


## input -> output 
# 인코더 RNN의 은닉 상태를 초기 은닉 상태(initial_state)로 사용
dec_emb = dec_emb_layer(decoder_inputs)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state = encoder_states) # initial_state = encoder_states : 글자(hidden state) 생성

# 모든 시점의 결과에 대해서 소프트맥스 함수를 사용한 출력층을 통해 단어 예측
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# 모델의 입력과 출력을 정의.
# seq2seq
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 64)     505920      ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, None, 256)    1156608     ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, 256),        328704      ['embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_1 (LSTM)                  [(None, None, 256),  525312      ['embedding_1[0][0]',
#                                  (None, 256),                     'lstm[0][1]',
#                                  (None, 256)]                     'lstm[0][2]']
#
#  dense (Dense)                  (None, None, 4518)   1161126     ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 3,677,670
# Trainable params: 3,677,670
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model.png', )

# %%
# callbacks : earlystopping, checkpoint (중요) // tensorboard
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', restore_best_weights=True, patience=3)

history = model.fit(x = [encoder_input_train, decoder_input_train], 
          y = decoder_target_train, 
          validation_data = ([encoder_input_test, decoder_input_test], decoder_target_test),
          batch_size = BATCH_SIZE, 
          callbacks = [earlystopping],
          epochs = 20)
# Out:
# Epoch 1/20
# 465/465 [==============================] - 35s 53ms/step - loss: 2.7548 - acc: 0.5642 - val_loss: 2.2166 - val_acc: 0.6371
# Epoch 2/20
# 465/465 [==============================] - 6s 12ms/step - loss: 2.0849 - acc: 0.6433 - val_loss: 2.0167 - val_acc: 0.6503
# Epoch 3/20
# 465/465 [==============================] - 6s 13ms/step - loss: 1.8795 - acc: 0.6613 - val_loss: 1.8168 - val_acc: 0.6735
# Epoch 4/20
# 465/465 [==============================] - 5s 11ms/step - loss: 1.6512 - acc: 0.6909 - val_loss: 1.6538 - val_acc: 0.7027
# Epoch 5/20
# 465/465 [==============================] - 6s 12ms/step - loss: 1.5047 - acc: 0.7113 - val_loss: 1.5513 - val_acc: 0.7159
# Epoch 6/20
# 465/465 [==============================] - 7s 15ms/step - loss: 1.3857 - acc: 0.7270 - val_loss: 1.4735 - val_acc: 0.7257
# Epoch 7/20
# 465/465 [==============================] - 5s 10ms/step - loss: 1.2787 - acc: 0.7412 - val_loss: 1.4030 - val_acc: 0.7372
# Epoch 8/20
# 465/465 [==============================] - 6s 12ms/step - loss: 1.1832 - acc: 0.7565 - val_loss: 1.3298 - val_acc: 0.7512
# Epoch 9/20
# 465/465 [==============================] - 5s 11ms/step - loss: 1.0945 - acc: 0.7703 - val_loss: 1.2823 - val_acc: 0.7591
# Epoch 10/20
# 465/465 [==============================] - 7s 15ms/step - loss: 1.0167 - acc: 0.7823 - val_loss: 1.2394 - val_acc: 0.7668
# Epoch 11/20
# 465/465 [==============================] - 5s 10ms/step - loss: 0.9452 - acc: 0.7933 - val_loss: 1.2050 - val_acc: 0.7723
# Epoch 12/20
# 465/465 [==============================] - 6s 12ms/step - loss: 0.8798 - acc: 0.8037 - val_loss: 1.1567 - val_acc: 0.7817
# Epoch 13/20
# 465/465 [==============================] - 6s 12ms/step - loss: 0.8195 - acc: 0.8135 - val_loss: 1.1352 - val_acc: 0.7864
# Epoch 14/20
# 465/465 [==============================] - 5s 10ms/step - loss: 0.7639 - acc: 0.8232 - val_loss: 1.1089 - val_acc: 0.7911
# Epoch 15/20
# 465/465 [==============================] - 6s 13ms/step - loss: 0.7086 - acc: 0.8332 - val_loss: 1.0838 - val_acc: 0.7962
# Epoch 16/20
# 465/465 [==============================] - 7s 14ms/step - loss: 0.6568 - acc: 0.8428 - val_loss: 1.0579 - val_acc: 0.8026
# Epoch 17/20
# 465/465 [==============================] - 6s 13ms/step - loss: 0.6079 - acc: 0.8519 - val_loss: 1.0405 - val_acc: 0.8060
# Epoch 18/20
# 465/465 [==============================] - 5s 10ms/step - loss: 0.5610 - acc: 0.8620 - val_loss: 1.0217 - val_acc: 0.8114
# Epoch 19/20
# 465/465 [==============================] - 5s 10ms/step - loss: 0.5148 - acc: 0.8717 - val_loss: 1.0089 - val_acc: 0.8159
# Epoch 20/20
# 465/465 [==============================] - 6s 12ms/step - loss: 0.4738 - acc: 0.8803 - val_loss: 1.0014 - val_acc: 0.8166

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure(figsize=(12, 6))

  plt.subplot(1,2,1)
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.plot(hist['epoch'], hist['loss'],
           label='Train Loss')
  plt.plot(hist['epoch'], hist['val_loss'],
           label = 'Val Loss')
  plt.ylim([0,5])
  plt.legend()

  plt.subplot(1,2,2)
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.plot(hist['epoch'], hist['acc'],
           label='Train Acc')
  plt.plot(hist['epoch'], hist['val_acc'],
           label = 'Val Acc')
  plt.ylim([0,1])
  plt.legend()
  plt.show()

plot_history(history)

# %% [markdown]
# ## Inference
#
# - 학습된 모델을 바탕으로 번역기를 만들어봅시다. -> 즉 inference용 번역기
#
# - *교사 강요(teacher forcing)*를 사용하기 못하는 것을 제외하고는 훈련 루프와 비슷합니다. 각 마지막 시점(time step)에서 이전 디코더 인코더의 결과와 은닉 상태(hidden state)를 가진 예측 값을 디코더에 입력합니다.
#
#     1. 번역하고자 하는 입력 문장이 인코더로 입력되어 인코더의 마지막 시점의 은닉 상태와 셀 상태를 얻습니다.
#     2. 인코더의 은닉 상태와 셀 상태, 그리고 토큰 <sos>를 디코더로 보냅니다.
#     3. 디코더가 토큰 <eos>가 나올 때까지 다음 단어를 예측하는 행동을 반복합니다.

# %%
# 인코더 - 훈련과 동일
encoder_model = Model(encoder_inputs, encoder_states)

# %%
# 디코더 (Predict)

# Input Tensors : 이전 시점의 상태를 보관할 텐서
decoder_input_h = Input(shape=(HIDDEN_DIM,))
decoder_input_c = Input(shape=(HIDDEN_DIM,))

decoder_states_inputs = [decoder_input_h, decoder_input_c] # input context vector

# 훈련 때 사용했던 임베딩 층을 재사용
x = dec_emb_layer(decoder_inputs) # input word - 처음: <sos> / 다음에는 이전 cell의 출력

# 다음 단어 예측을 위해 이전 시점의 상태를 현 시점의 초기 상태로 사용
x, state_h2, state_c2 = decoder_lstm(x, initial_state=decoder_states_inputs) # hidden, cell --> lstm output
decoder_states2 = [state_h2, state_c2]

# 모든 시점에 대해서 단어 예측 (Fully Connected)
x = decoder_dense(x)

# 수정된 디코더
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [x] + decoder_states2) # [x, state_h2, state_c2]

# %%
# 인코더 모델 시각화
tf.keras.utils.plot_model(encoder_model)

# %%
# 디코더 모델 시각화
# 디코더의 입력 3개 : embedding / hidden_state / cell_state
tf.keras.utils.plot_model(decoder_model)

# %% [markdown]
# 테스트 단계에서의 동작을 위한 decode_sequence 함수를 구현합니다.
# 1. 입력 문장이 들어오면 인코더는 마지막 시점까지 전개하여 마지막 시점의 은닉 상태와 셀 상태를 리턴합니다. -> `states_value`
# 2. 디코더의 초기 입력으로 <SOS>를 준비합니다. -> `target_seq`
# 3. 이 두 가지 입력을 가지고 while문 안으로 진입하여 이 두 가지를 디코더의 입력으로 사용합니다.
# 4. 이제 디코더는 현재 시점에 대해서 예측합니다.
#     - 예측 벡터로부터 현재 시점의 예측 단어인 target_seq를 얻고, h와 c 이 두 개의 값은 states_value에 저장합니다.
#     - while문의 다음 루프. 즉, 두번째 시점의 디코더의 입력으로 다시 target_seq와 states_value를 사용합니다.
#     - 이를 현재 시점의 예측 단어로 <eos>를 예측하거나 번역 문장의 길이가 50이 넘는 순간까지 반복합니다.
# 5. 각 시점마다 번역된 단어는 decoded_sentence에 누적하여 저장하였다가 최종 번역 시퀀스로 리턴합니다.

# %%
def translate(sentence):
    sentence = preprocess_sentence(sentence)
    tokens = sentence.split(" ")

    # 입력 문장 토큰 -> 라벨링
    enc_input = tokenizer_enc.texts_to_sequences([tokens]) # ex : [23, 56,2]

    # 입력 문장 라벨링 -> 패딩 
    enc_input = tf.keras.preprocessing.sequence.pad_sequences(enc_input, maxlen=MAX_ENC_LEN, padding='post') # ex : [23, 56, 2, ..., 0, 0, 0]
    
    # Encoder
    states_value = encoder_model.predict(enc_input) # context vector

    # Decoder input인 <SOS>에 해당하는 정수 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar2idx['<sos>']


    # prediction 시작
    # stop_condition이 True가 될 때까지 루프 반복
    # 구현의 간소화를 위해서 이 함수는 배치 크기를 1로 가정합니다.
    stop_condition = False
    decoded_sentence = ''

    for t in range(MAX_DEC_LEN):

        # 이점 시점의 상태 states_value를 현 시점의 초기 상태로 사용
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value, verbose = 0)

        # 예측 결과를 단어로 변환
        result_token_index = np.argmax(output_tokens[0, -1, :])
        result_word = idx2tar[result_token_index]

        # 현재 시점의 예측 단어를 예측 문장에 추가
        decoded_sentence += ' '+result_word

        # 현재 시점의 예측 결과 -> 다음 시점의 입력으로 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = result_token_index

        # 현재 시점의 상태 ->  다음 시점의 상태로 업데이트
        states_value = [h, c]

        #  Stop condition <eos>에 도달하면 중단.
        if result_word == '<eos>':
            break 

    return decoded_sentence.strip(' <eos>')

# %% [markdown]
# ## 결과 확인

# %% [markdown]
# 결과 확인을 위한 함수를 만듭니다.

# %%
train_idx = indices[:n_of_train]
test_idx = indices[n_of_train:]

# %%
n_samples = 5
np.random.choice(train_idx, n_samples)
# Out:
# array([ 9947, 13453, 24842, 16073, 31158])

# %%
# train data - translate
n_samples = 5
for idx in np.random.choice(train_idx, n_samples):
    test_sentence = fra_corpus[idx]
    answer_sentence = eng_corpus[idx]
    decoded_sentence = translate(test_sentence)

    print("입력문장 :", test_sentence)
    print("정답문장 :", answer_sentence) 
    print("번역문장 :", decoded_sentence)
    print("-"*50)
# Out:
# 1/1 [==============================] - 0s 382ms/step
# 입력문장 : Santé !
# 정답문장 : Bottoms up!
# 번역문장 : bottoms up !
# --------------------------------------------------
# 1/1 [==============================] - 0s 16ms/step
# 입력문장 : J'ai une voiture.
# 정답문장 : I have a car.
# 번역문장 : i have a computer .
# --------------------------------------------------
# 1/1 [==============================] - 0s 17ms/step
# 입력문장 : Encore une fois, merci.
# 정답문장 : Thanks again.
# 번역문장 : thanks a heap .
# --------------------------------------------------
# 1/1 [==============================] - 0s 16ms/step
# 입력문장 : C'est une erreur.
# 정답문장 : That's a mistake.
# 번역문장 : this is a fish .
# --------------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# 입력문장 : J'ai les cheveux mouillés.
# 정답문장 : My hair is wet.
# 번역문장 : i ve seen that .
# --------------------------------------------------

# %%
# test data - translate
n_samples = 5
for idx in np.random.choice(test_idx, n_samples):
    test_sentence = fra_corpus[idx]
    answer_sentence = eng_corpus[idx]
    decoded_sentence = translate(test_sentence)

    print("입력문장 :", test_sentence)
    print("정답문장 :", answer_sentence) 
    print("번역문장 :", decoded_sentence)
    print("-"*50)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 입력문장 : Je ne sais pas danser.
# 정답문장 : I can't dance.
# 번역문장 : i can t stand .
# --------------------------------------------------
# 1/1 [==============================] - 0s 16ms/step
# 입력문장 : Puis-je m'asseoir avec vous ?
# 정답문장 : Can I sit with you?
# 번역문장 : may i sit here ?
# --------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 입력문장 : Je veux un petit ami.
# 정답문장 : I want a boyfriend.
# 번역문장 : i want a puppy .
# --------------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# 입력문장 : Je peux vous attendre.
# 정답문장 : I can wait for you.
# 번역문장 : i can t help you .
# --------------------------------------------------
# 1/1 [==============================] - 0s 17ms/step
# 입력문장 : Levez-vous !
# 정답문장 : Get on your feet.
# 번역문장 : get away from here .
# --------------------------------------------------

# %% [markdown]
# ## BLEU Score (Bilingual Evaluation Understudy Score)
# 기계 번역의 성능이 얼마나 뛰어난가를 측정하기 위해 사용되는 대표적인 방법 중 하나인 BLEU(Bilingual Evaluation Understudy)를 측정해봅시다.
# - 논문 : BLEU: a Method for Automatic Evaluation of Machine Translation
# - BLEU 점수는 기계 번역된 텍스트와 고품질 참조 번역 세트의 유사성을 측정하는 0과 1 사이의 숫자입니다.
#     - 값이 0이면 기계 번역된 출력이 참조 번역과 겹치는 부분이 없는 것을 의미하고(저품질)
#     - 1이면 참조 번역과 완벽하게 겹치는 것을 의미합니다(고품질)
#
# - BLEU 설명
#     - https://jrc-park.tistory.com/273
#     - https://wikidocs.net/31695
#     - https://cloud.google.com/translate/automl/docs/evaluate?hl=ko#bleu

# %% [markdown]
# BLEU는 기계 번역 결과와 사람이 직접 번역한 결과가 얼마나 유사한지 비교하여 번역에 대한 성능을 측정하는 방법입니다.

# %%
# !pip install evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 5.3 MB/s eta 0:00:00
# Collecting datasets>=2.0.0
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 12.9 MB/s eta 0:00:00
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.4 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 23.9 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.7.0
#   Downloading huggingface_hub-0.14.0-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.2/224.2 kB 29.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (2023.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from evaluate) (23.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from evaluate) (1.22.4)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 17.3 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (2.27.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from evaluate) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate) (6.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.8 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate) (9.0.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.11.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (2.0.12)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->evaluate) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->evaluate) (2.8.2)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.3/269.3 kB 29.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 21.3 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 13.7 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets, evaluate
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 evaluate-0.4.0 frozenlist-1.3.3 huggingface-hub-0.14.0 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.9.1

# %%
import evaluate 
predictions = ["hello there general kenobi", "foo bar foobar"]
references = [
    ["hello there general kenobi", "hello there !"],
    ["foo bar foobar"]
 ]

bleu = evaluate.load("bleu")

results = bleu.compute(predictions=predictions, references=references)

print(results)
# Out:
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# {'bleu': 1.0, 'precisions': [1.0, 1.0, 1.0, 1.0], 'brevity_penalty': 1.0, 'length_ratio': 1.1666666666666667, 'translation_length': 7, 'reference_length': 6}

# %%
from tqdm.notebook import tqdm 

n_samples = 10
ref_train, pred_train = [], []
for idx in tqdm(np.random.choice(test_idx, n_samples)):
    ref_train.append(eng_corpus[idx])
    pred_train.append(translate(fra_corpus[idx]))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
print(ref_train) 
print(pred_train)
# Out:
# ["I didn't register.", 'Can we talk?', "I'm proud of that.", "Let's kiss.", "It's unlocked.", "I'm in charge here.", 'Can you show me?', "It'll work.", "That's true.", 'I was born in 1972.']
# ['i didn t stop .', 'can we go ?', 'i m proud of that .', 'let s move .', 'it s easily done .', 'i m the boss .', 'do animals eat fish ?', 'it ll work .', 'this is correct .', 'i m not here .']

# %%
bleu.compute(predictions=pred_train, references=ref_train)
# Out:
# {'bleu': 0.11073049583498255,
#  'precisions': [0.3191489361702128,
#   0.10810810810810811,
#   0.07407407407407407,
#   0.058823529411764705],
#  'brevity_penalty': 1.0,
#  'length_ratio': 1.146341463414634,
#  'translation_length': 47,
#  'reference_length': 41}

# %% [markdown]
# ### Reference
#
# - https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html
# - https://wikidocs.net/86900
